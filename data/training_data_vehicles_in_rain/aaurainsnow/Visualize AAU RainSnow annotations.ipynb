# %%
from pycocotools import coco
import numpy as np
import skimage.io as io
import matplotlib
import matplotlib.pyplot as plt
import pylab
import random
import cv2
pylab.rcParams['figure.figsize'] = (8.0, 6.0)

rgbAnnFile='./aauRainSnow-rgb.json'
thermalAnnFile = './aauRainSnow-thermal.json'

rainSnowRgbGt = coco.COCO(rgbAnnFile)
rainSnowThermalGt = coco.COCO(thermalAnnFile)
# Out:
# loading annotations into memory...
# Done (t=0.73s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=2.18s)
# creating index...
# index created!

# %% [markdown]
# ## Display a random image with overlayed annotations in both the RGB and thermal domain

# %%
for i in range(0, 2197):
    chosenImgId = i
    annIds = rainSnowRgbGt.getAnnIds(imgIds=[chosenImgId])
    anns = rainSnowRgbGt.loadAnns(annIds)

    rgbImg = rainSnowRgbGt.loadImgs([chosenImgId])[0]
    thermalImg = rainSnowThermalGt.loadImgs([chosenImgId])[0]
    thermalAnns = rainSnowThermalGt.loadAnns(annIds)

    print('Found ' + str(len(anns)) + ' annotations at image ID ' + str(chosenImgId) + '. Image file: ' + rgbImg['file_name'])

    for ann in anns:
        print('Annotation #' + str(ann['id']) + ': ' + rainSnowRgbGt.loadCats(ann['category_id'])[0]['name'])

    matplotlib.rcParams['interactive'] == False
    print("\nRGB Image")
    I = io.imread('./' + rgbImg['file_name'])
    plt.gcf().clear()
    plt.axis('off')
    plt.imshow(I);
    rainSnowRgbGt.showAnns(anns)
    plt.show()

    # For some reason, the image won't show in some Windows/Anaconda configurations. If this is the case, print the image instead
    plt.savefig("Samples/rgb-" + str(chosenImgId).zfill(5) + ".png")

    print("\nThermal Image")
    # Load thermal annotations
    I = io.imread('./' + thermalImg['file_name'])
    plt.gcf().clear()
    plt.axis('off')
    plt.imshow(I);
    rainSnowThermalGt.showAnns(thermalAnns)
    plt.show()

    plt.savefig("Samples/thermal-" + str(chosenImgId).zfill(5) + ".png")
# Out:
# Found 3 annotations at image ID 0. Image file: Egensevej/Egensevej-1/cam1-00055.png
# Annotation #0: car
# Annotation #1: car
# Annotation #2: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 1. Image file: Egensevej/Egensevej-1/cam1-00141.png
# Annotation #3: car
# Annotation #4: car
# Annotation #5: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2. Image file: Egensevej/Egensevej-1/cam1-00218.png
# Annotation #6: car
# Annotation #7: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 3. Image file: Egensevej/Egensevej-1/cam1-00219.png
# Annotation #8: car
# Annotation #9: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 4. Image file: Egensevej/Egensevej-1/cam1-00223.png
# Annotation #10: car
# Annotation #11: car
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 5. Image file: Egensevej/Egensevej-1/cam1-00447.png
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 6. Image file: Egensevej/Egensevej-1/cam1-00576.png
# Annotation #12: car
# Annotation #13: car
# Annotation #14: car
# Annotation #15: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 7. Image file: Egensevej/Egensevej-1/cam1-00609.png
# Annotation #16: car
# Annotation #17: car
# Annotation #18: car
# Annotation #19: car
# Annotation #20: car
# Annotation #21: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 8. Image file: Egensevej/Egensevej-1/cam1-00640.png
# Annotation #22: car
# Annotation #23: car
# Annotation #24: car
# Annotation #25: car
# Annotation #26: car
# Annotation #27: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 9. Image file: Egensevej/Egensevej-1/cam1-00700.png
# Annotation #28: car
# Annotation #29: car
# Annotation #30: car
# Annotation #31: car
# Annotation #32: car
# Annotation #33: car
# Annotation #34: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 10. Image file: Egensevej/Egensevej-1/cam1-00724.png
# Annotation #35: car
# Annotation #36: car
# Annotation #37: car
# Annotation #38: car
# Annotation #39: car
# Annotation #40: car
# Annotation #41: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 11. Image file: Egensevej/Egensevej-1/cam1-00795.png
# Annotation #42: car
# Annotation #43: car
# Annotation #44: car
# Annotation #45: car
# Annotation #46: car
# Annotation #47: car
# Annotation #48: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 12. Image file: Egensevej/Egensevej-1/cam1-00868.png
# Annotation #49: car
# Annotation #50: car
# Annotation #51: car
# Annotation #52: car
# Annotation #53: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 13. Image file: Egensevej/Egensevej-1/cam1-00940.png
# Annotation #54: car
# Annotation #55: car
# Annotation #56: car
# Annotation #57: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 14. Image file: Egensevej/Egensevej-1/cam1-01040.png
# Annotation #58: car
# Annotation #59: car
# Annotation #60: car
# Annotation #61: car
# Annotation #62: car
# Annotation #63: car
# Annotation #64: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 15. Image file: Egensevej/Egensevej-1/cam1-01091.png
# Annotation #65: car
# Annotation #66: car
# Annotation #67: car
# Annotation #68: car
# Annotation #69: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 16. Image file: Egensevej/Egensevej-1/cam1-01122.png
# Annotation #70: car
# Annotation #71: car
# Annotation #72: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 17. Image file: Egensevej/Egensevej-1/cam1-01248.png
# Annotation #73: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 18. Image file: Egensevej/Egensevej-1/cam1-01254.png
# Annotation #74: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 19. Image file: Egensevej/Egensevej-1/cam1-01303.png
# Annotation #75: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 20. Image file: Egensevej/Egensevej-1/cam1-01316.png
# Annotation #76: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 21. Image file: Egensevej/Egensevej-1/cam1-01353.png
# Annotation #77: car
# Annotation #78: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 22. Image file: Egensevej/Egensevej-1/cam1-01378.png
# Annotation #79: car
# Annotation #80: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 23. Image file: Egensevej/Egensevej-1/cam1-01397.png
# Annotation #81: car
# Annotation #82: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 24. Image file: Egensevej/Egensevej-1/cam1-01452.png
# Annotation #83: car
# Annotation #84: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 25. Image file: Egensevej/Egensevej-1/cam1-01462.png
# Annotation #85: car
# Annotation #86: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 26. Image file: Egensevej/Egensevej-1/cam1-01567.png
# Annotation #87: car
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 27. Image file: Egensevej/Egensevej-1/cam1-01609.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 28. Image file: Egensevej/Egensevej-1/cam1-01716.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 29. Image file: Egensevej/Egensevej-1/cam1-01731.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 30. Image file: Egensevej/Egensevej-1/cam1-01745.png
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 31. Image file: Egensevej/Egensevej-1/cam1-01885.png
# Annotation #88: car
# Annotation #89: car
# Annotation #90: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 32. Image file: Egensevej/Egensevej-1/cam1-02055.png
# Annotation #91: car
# Annotation #92: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 33. Image file: Egensevej/Egensevej-1/cam1-02062.png
# Annotation #93: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 34. Image file: Egensevej/Egensevej-1/cam1-02091.png
# Annotation #94: car
# Annotation #95: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 35. Image file: Egensevej/Egensevej-1/cam1-02148.png
# Annotation #96: car
# Annotation #97: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 36. Image file: Egensevej/Egensevej-1/cam1-02272.png
# Annotation #98: car
# Annotation #99: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 37. Image file: Egensevej/Egensevej-1/cam1-02305.png
# Annotation #100: car
# Annotation #101: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 38. Image file: Egensevej/Egensevej-1/cam1-02315.png
# Annotation #102: car
# Annotation #103: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 39. Image file: Egensevej/Egensevej-1/cam1-02423.png
# Annotation #104: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 40. Image file: Egensevej/Egensevej-1/cam1-02470.png
# Annotation #105: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 41. Image file: Egensevej/Egensevej-1/cam1-02560.png
# Annotation #106: car
# Annotation #107: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 42. Image file: Egensevej/Egensevej-1/cam1-02771.png
# Annotation #108: car
# Annotation #109: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 43. Image file: Egensevej/Egensevej-1/cam1-02872.png
# Annotation #110: car
# Annotation #111: car
# Annotation #112: car
# Annotation #113: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 44. Image file: Egensevej/Egensevej-1/cam1-02904.png
# Annotation #114: car
# Annotation #115: car
# Annotation #116: car
# Annotation #117: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 45. Image file: Egensevej/Egensevej-1/cam1-03003.png
# Annotation #118: car
# Annotation #119: car
# Annotation #120: car
# Annotation #121: car
# Annotation #122: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 46. Image file: Egensevej/Egensevej-1/cam1-03069.png
# Annotation #123: car
# Annotation #124: car
# Annotation #125: car
# Annotation #126: car
# Annotation #127: car
# Annotation #128: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 47. Image file: Egensevej/Egensevej-1/cam1-03168.png
# Annotation #129: car
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 48. Image file: Egensevej/Egensevej-1/cam1-03282.png
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 49. Image file: Egensevej/Egensevej-1/cam1-03501.png
# Annotation #130: car
# Annotation #131: car
# Annotation #132: car
#
# RGB Image
# Thermal Image
# Found 3 annotations at image ID 50. Image file: Egensevej/Egensevej-1/cam1-03512.png
# Annotation #133: car
# Annotation #134: car
# Annotation #135: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 51. Image file: Egensevej/Egensevej-1/cam1-03531.png
# Annotation #136: car
# Annotation #137: car
# Annotation #138: car
# Annotation #139: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 52. Image file: Egensevej/Egensevej-1/cam1-03578.png
# Annotation #140: car
# Annotation #141: car
# Annotation #142: car
# Annotation #143: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 53. Image file: Egensevej/Egensevej-1/cam1-03611.png
# Annotation #144: car
# Annotation #145: car
# Annotation #146: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 54. Image file: Egensevej/Egensevej-1/cam1-03650.png
# Annotation #147: car
# Annotation #148: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 55. Image file: Egensevej/Egensevej-1/cam1-03751.png
# Annotation #149: car
# Annotation #150: car
# Annotation #151: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 56. Image file: Egensevej/Egensevej-1/cam1-03891.png
# Annotation #152: car
# Annotation #153: car
# Annotation #154: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 57. Image file: Egensevej/Egensevej-1/cam1-03895.png
# Annotation #155: car
# Annotation #156: car
# Annotation #157: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 58. Image file: Egensevej/Egensevej-1/cam1-03901.png
# Annotation #158: car
# Annotation #159: car
# Annotation #160: bus
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 59. Image file: Egensevej/Egensevej-1/cam1-04016.png
# Annotation #161: car
# Annotation #162: bus
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 60. Image file: Egensevej/Egensevej-1/cam1-04023.png
# Annotation #163: car
# Annotation #164: bus
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 61. Image file: Egensevej/Egensevej-1/cam1-04051.png
# Annotation #165: car
# Annotation #166: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 62. Image file: Egensevej/Egensevej-1/cam1-04151.png
# Annotation #167: car
# Annotation #168: car
# Annotation #169: bus
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 63. Image file: Egensevej/Egensevej-1/cam1-04254.png
# Annotation #170: car
# Annotation #171: bus
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 64. Image file: Egensevej/Egensevej-1/cam1-04439.png
# Annotation #172: car
# Annotation #173: car
# Annotation #174: bus
# Annotation #175: car
# Annotation #176: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 65. Image file: Egensevej/Egensevej-1/cam1-04509.png
# Annotation #177: car
# Annotation #178: car
# Annotation #179: bus
# Annotation #180: car
# Annotation #181: car
# Annotation #182: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 66. Image file: Egensevej/Egensevej-1/cam1-04590.png
# Annotation #183: car
# Annotation #184: car
# Annotation #185: bus
# Annotation #186: car
# Annotation #187: car
# Annotation #188: car
# Annotation #189: car
# Annotation #190: car
# Annotation #191: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 67. Image file: Egensevej/Egensevej-1/cam1-04596.png
# Annotation #192: car
# Annotation #193: car
# Annotation #194: bus
# Annotation #195: car
# Annotation #196: car
# Annotation #197: car
# Annotation #198: car
# Annotation #199: car
# Annotation #200: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 68. Image file: Egensevej/Egensevej-1/cam1-04779.png
# Annotation #201: car
# Annotation #202: car
# Annotation #203: bus
# Annotation #204: car
# Annotation #205: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 69. Image file: Egensevej/Egensevej-1/cam1-04880.png
# Annotation #206: car
# Annotation #207: car
# Annotation #208: bus
# Annotation #209: car
# Annotation #210: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 70. Image file: Egensevej/Egensevej-1/cam1-04932.png
# Annotation #211: car
# Annotation #212: bus
# Annotation #213: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 71. Image file: Egensevej/Egensevej-1/cam1-04985.png
# Annotation #214: car
# Annotation #215: car
# Annotation #216: bus
# Annotation #217: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 72. Image file: Egensevej/Egensevej-1/cam1-04995.png
# Annotation #218: car
# Annotation #219: car
# Annotation #220: bus
# Annotation #221: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 73. Image file: Egensevej/Egensevej-1/cam1-05034.png
# Annotation #222: car
# Annotation #223: car
# Annotation #224: bus
# Annotation #225: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 74. Image file: Egensevej/Egensevej-1/cam1-05062.png
# Annotation #226: car
# Annotation #227: bus
# Annotation #228: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 75. Image file: Egensevej/Egensevej-1/cam1-05074.png
# Annotation #229: car
# Annotation #230: bus
# Annotation #231: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 76. Image file: Egensevej/Egensevej-1/cam1-05187.png
# Annotation #232: car
# Annotation #233: car
# Annotation #234: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 77. Image file: Egensevej/Egensevej-1/cam1-05198.png
# Annotation #235: car
# Annotation #236: car
# Annotation #237: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 78. Image file: Egensevej/Egensevej-1/cam1-05231.png
# Annotation #238: car
# Annotation #239: car
# Annotation #240: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 79. Image file: Egensevej/Egensevej-1/cam1-05234.png
# Annotation #241: car
# Annotation #242: car
# Annotation #243: bus
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 80. Image file: Egensevej/Egensevej-1/cam1-05238.png
# Annotation #244: car
# Annotation #245: bus
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 81. Image file: Egensevej/Egensevej-1/cam1-05287.png
# Annotation #246: car
# Annotation #247: car
# Annotation #248: bus
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 82. Image file: Egensevej/Egensevej-1/cam1-05353.png
# Annotation #249: car
# Annotation #250: car
# Annotation #251: bus
# Annotation #252: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 83. Image file: Egensevej/Egensevej-1/cam1-05362.png
# Annotation #253: car
# Annotation #254: car
# Annotation #255: bus
# Annotation #256: car
# Annotation #257: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 84. Image file: Egensevej/Egensevej-1/cam1-05450.png
# Annotation #258: car
# Annotation #259: bus
# Annotation #260: car
# Annotation #261: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 85. Image file: Egensevej/Egensevej-1/cam1-05479.png
# Annotation #262: car
# Annotation #263: bus
# Annotation #264: car
# Annotation #265: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 86. Image file: Egensevej/Egensevej-1/cam1-05535.png
# Annotation #266: car
# Annotation #267: car
# Annotation #268: bus
# Annotation #269: car
# Annotation #270: car
# Annotation #271: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 87. Image file: Egensevej/Egensevej-1/cam1-05553.png
# Annotation #272: car
# Annotation #273: car
# Annotation #274: bus
# Annotation #275: car
# Annotation #276: car
# Annotation #277: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 88. Image file: Egensevej/Egensevej-1/cam1-05719.png
# Annotation #278: car
# Annotation #279: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 89. Image file: Egensevej/Egensevej-1/cam1-05733.png
# Annotation #280: car
# Annotation #281: car
# Annotation #282: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 90. Image file: Egensevej/Egensevej-1/cam1-05779.png
# Annotation #283: car
# Annotation #284: car
# Annotation #285: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 91. Image file: Egensevej/Egensevej-1/cam1-05786.png
# Annotation #286: car
# Annotation #287: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 92. Image file: Egensevej/Egensevej-1/cam1-05788.png
# Annotation #288: car
# Annotation #289: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 93. Image file: Egensevej/Egensevej-1/cam1-05809.png
# Annotation #290: car
# Annotation #291: car
#
# RGB Image
# Thermal Image
# Found 3 annotations at image ID 94. Image file: Egensevej/Egensevej-1/cam1-05848.png
# Annotation #292: car
# Annotation #293: car
# Annotation #294: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 95. Image file: Egensevej/Egensevej-1/cam1-05859.png
# Annotation #295: car
# Annotation #296: car
# Annotation #297: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 96. Image file: Egensevej/Egensevej-1/cam1-05863.png
# Annotation #298: car
# Annotation #299: car
# Annotation #300: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 97. Image file: Egensevej/Egensevej-1/cam1-05963.png
# Annotation #301: car
# Annotation #302: car
# Annotation #303: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 98. Image file: Egensevej/Egensevej-1/cam1-05980.png
# Annotation #304: car
# Annotation #305: car
# Annotation #306: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 99. Image file: Egensevej/Egensevej-1/cam1-05990.png
# Annotation #307: car
# Annotation #308: car
# Annotation #309: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 100. Image file: Egensevej/Egensevej-2/cam1-00065.png
# Annotation #310: car
# Annotation #311: bus
# Annotation #312: car
# Annotation #313: car
# Annotation #314: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 101. Image file: Egensevej/Egensevej-2/cam1-00116.png
# Annotation #315: truck
# Annotation #316: bus
# Annotation #317: car
# Annotation #318: car
# Annotation #319: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 102. Image file: Egensevej/Egensevej-2/cam1-00199.png
# Annotation #320: truck
# Annotation #321: bus
# Annotation #322: truck
# Annotation #323: car
# Annotation #324: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 103. Image file: Egensevej/Egensevej-2/cam1-00259.png
# Annotation #325: truck
# Annotation #326: bus
# Annotation #327: truck
# Annotation #328: car
# Annotation #329: car
# Annotation #330: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 104. Image file: Egensevej/Egensevej-2/cam1-00383.png
# Annotation #331: truck
# Annotation #332: car
# Annotation #333: truck
# Annotation #334: car
# Annotation #335: car
# Annotation #336: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 105. Image file: Egensevej/Egensevej-2/cam1-00385.png
# Annotation #337: truck
# Annotation #338: car
# Annotation #339: truck
# Annotation #340: car
# Annotation #341: car
# Annotation #342: car
# Annotation #343: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 106. Image file: Egensevej/Egensevej-2/cam1-00395.png
# Annotation #344: truck
# Annotation #345: car
# Annotation #346: car
# Annotation #347: car
# Annotation #348: car
# Annotation #349: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 107. Image file: Egensevej/Egensevej-2/cam1-00419.png
# Annotation #350: truck
# Annotation #351: car
# Annotation #352: car
# Annotation #353: car
# Annotation #354: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 108. Image file: Egensevej/Egensevej-2/cam1-00430.png
# Annotation #355: truck
# Annotation #356: car
# Annotation #357: car
# Annotation #358: car
# Annotation #359: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 109. Image file: Egensevej/Egensevej-2/cam1-00576.png
# Annotation #360: car
# Annotation #361: car
# Annotation #626: car
# Annotation #630: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 110. Image file: Egensevej/Egensevej-2/cam1-00665.png
# Annotation #362: car
# Annotation #363: car
# Annotation #631: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 111. Image file: Egensevej/Egensevej-2/cam1-00681.png
# Annotation #364: car
# Annotation #627: car
# Annotation #632: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 112. Image file: Egensevej/Egensevej-2/cam1-00722.png
# Annotation #365: car
# Annotation #366: car
# Annotation #633: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 113. Image file: Egensevej/Egensevej-2/cam1-00742.png
# Annotation #367: car
# Annotation #368: car
# Annotation #369: car
# Annotation #634: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 114. Image file: Egensevej/Egensevej-2/cam1-00796.png
# Annotation #370: car
# Annotation #371: car
# Annotation #372: car
# Annotation #635: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 115. Image file: Egensevej/Egensevej-2/cam1-00812.png
# Annotation #373: car
# Annotation #374: car
# Annotation #375: car
# Annotation #636: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 116. Image file: Egensevej/Egensevej-2/cam1-00822.png
# Annotation #376: car
# Annotation #377: car
# Annotation #378: car
# Annotation #637: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 117. Image file: Egensevej/Egensevej-2/cam1-00858.png
# Annotation #379: car
# Annotation #380: car
# Annotation #381: car
# Annotation #638: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 118. Image file: Egensevej/Egensevej-2/cam1-00880.png
# Annotation #382: car
# Annotation #383: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 119. Image file: Egensevej/Egensevej-2/cam1-00961.png
# Annotation #384: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 120. Image file: Egensevej/Egensevej-2/cam1-01019.png
# Annotation #385: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 121. Image file: Egensevej/Egensevej-2/cam1-01148.png
# Annotation #386: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 122. Image file: Egensevej/Egensevej-2/cam1-01168.png
# Annotation #387: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 123. Image file: Egensevej/Egensevej-2/cam1-01237.png
# Annotation #388: car
# Annotation #389: truck
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 124. Image file: Egensevej/Egensevej-2/cam1-01643.png
# Annotation #390: car
# Annotation #391: car
# Annotation #392: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 125. Image file: Egensevej/Egensevej-2/cam1-01697.png
# Annotation #393: car
# Annotation #394: car
# Annotation #395: car
# Annotation #396: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 126. Image file: Egensevej/Egensevej-2/cam1-01768.png
# Annotation #397: car
# Annotation #398: car
# Annotation #399: car
# Annotation #400: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 127. Image file: Egensevej/Egensevej-2/cam1-01785.png
# Annotation #401: car
# Annotation #402: car
# Annotation #403: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 128. Image file: Egensevej/Egensevej-2/cam1-01836.png
# Annotation #404: car
# Annotation #405: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 129. Image file: Egensevej/Egensevej-2/cam1-01842.png
# Annotation #406: car
# Annotation #407: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 130. Image file: Egensevej/Egensevej-2/cam1-01948.png
# Annotation #408: car
# Annotation #409: car
# Annotation #410: car
# Annotation #411: car
# Annotation #628: truck
# Annotation #639: truck
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 131. Image file: Egensevej/Egensevej-2/cam1-02006.png
# Annotation #412: car
# Annotation #413: truck
# Annotation #414: car
# Annotation #415: car
# Annotation #640: truck
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 132. Image file: Egensevej/Egensevej-2/cam1-02056.png
# Annotation #416: car
# Annotation #417: truck
# Annotation #418: car
# Annotation #419: car
# Annotation #641: truck
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 133. Image file: Egensevej/Egensevej-2/cam1-02060.png
# Annotation #420: car
# Annotation #421: truck
# Annotation #422: car
# Annotation #423: car
# Annotation #642: truck
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 134. Image file: Egensevej/Egensevej-2/cam1-02180.png
# Annotation #424: car
# Annotation #425: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 135. Image file: Egensevej/Egensevej-2/cam1-02203.png
# Annotation #426: car
# Annotation #427: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 136. Image file: Egensevej/Egensevej-2/cam1-02401.png
# Annotation #428: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 137. Image file: Egensevej/Egensevej-2/cam1-02428.png
# Annotation #429: car
#
# RGB Image
# Thermal Image
# Found 1 annotations at image ID 138. Image file: Egensevej/Egensevej-2/cam1-02453.png
# Annotation #430: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 139. Image file: Egensevej/Egensevej-2/cam1-02547.png
# Annotation #431: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 140. Image file: Egensevej/Egensevej-2/cam1-02553.png
# Annotation #432: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 141. Image file: Egensevej/Egensevej-2/cam1-02658.png
# Annotation #433: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 142. Image file: Egensevej/Egensevej-2/cam1-02922.png
# Annotation #434: car
# Annotation #435: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 143. Image file: Egensevej/Egensevej-2/cam1-02927.png
# Annotation #436: car
# Annotation #437: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 144. Image file: Egensevej/Egensevej-2/cam1-02938.png
# Annotation #438: car
# Annotation #439: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 145. Image file: Egensevej/Egensevej-2/cam1-03058.png
# Annotation #440: car
# Annotation #441: car
# Annotation #442: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 146. Image file: Egensevej/Egensevej-2/cam1-03086.png
# Annotation #443: car
# Annotation #444: car
# Annotation #445: car
# Annotation #446: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 147. Image file: Egensevej/Egensevej-2/cam1-03264.png
# Annotation #447: car
# Annotation #448: car
# Annotation #449: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 148. Image file: Egensevej/Egensevej-2/cam1-03330.png
# Annotation #450: car
# Annotation #451: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 149. Image file: Egensevej/Egensevej-2/cam1-03364.png
# Annotation #452: car
# Annotation #453: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 150. Image file: Egensevej/Egensevej-2/cam1-03367.png
# Annotation #454: car
# Annotation #455: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 151. Image file: Egensevej/Egensevej-2/cam1-03435.png
# Annotation #456: car
# Annotation #457: car
# Annotation #458: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 152. Image file: Egensevej/Egensevej-2/cam1-03667.png
# Annotation #459: car
# Annotation #460: car
# Annotation #461: car
# Annotation #462: car
# Annotation #629: truck
# Annotation #643: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 153. Image file: Egensevej/Egensevej-2/cam1-03689.png
# Annotation #463: car
# Annotation #464: car
# Annotation #465: car
# Annotation #466: car
# Annotation #467: truck
# Annotation #644: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 154. Image file: Egensevej/Egensevej-2/cam1-03841.png
# Annotation #468: car
# Annotation #469: car
# Annotation #470: car
# Annotation #471: car
# Annotation #472: truck
# Annotation #473: car
# Annotation #474: car
# Annotation #645: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 155. Image file: Egensevej/Egensevej-2/cam1-03852.png
# Annotation #475: car
# Annotation #476: car
# Annotation #477: car
# Annotation #478: car
# Annotation #479: truck
# Annotation #480: car
# Annotation #481: car
# Annotation #646: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 156. Image file: Egensevej/Egensevej-2/cam1-03884.png
# Annotation #482: car
# Annotation #483: car
# Annotation #484: car
# Annotation #485: car
# Annotation #486: truck
# Annotation #487: car
# Annotation #488: car
# Annotation #647: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 157. Image file: Egensevej/Egensevej-2/cam1-03886.png
# Annotation #489: car
# Annotation #490: car
# Annotation #491: car
# Annotation #492: car
# Annotation #493: truck
# Annotation #494: car
# Annotation #495: car
# Annotation #648: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 158. Image file: Egensevej/Egensevej-2/cam1-03898.png
# Annotation #496: car
# Annotation #497: car
# Annotation #498: car
# Annotation #499: car
# Annotation #500: truck
# Annotation #501: car
# Annotation #502: car
# Annotation #649: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 159. Image file: Egensevej/Egensevej-2/cam1-03917.png
# Annotation #503: car
# Annotation #504: car
# Annotation #505: car
# Annotation #506: car
# Annotation #507: truck
# Annotation #508: car
# Annotation #509: car
# Annotation #650: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 160. Image file: Egensevej/Egensevej-2/cam1-03944.png
# Annotation #510: car
# Annotation #511: car
# Annotation #512: car
# Annotation #513: truck
# Annotation #514: car
# Annotation #515: car
# Annotation #651: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 161. Image file: Egensevej/Egensevej-2/cam1-03980.png
# Annotation #516: car
# Annotation #517: car
# Annotation #518: car
# Annotation #519: truck
# Annotation #520: car
# Annotation #521: car
# Annotation #652: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 162. Image file: Egensevej/Egensevej-2/cam1-04095.png
# Annotation #522: car
# Annotation #523: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 163. Image file: Egensevej/Egensevej-2/cam1-04135.png
# Annotation #524: car
# Annotation #525: car
# Annotation #526: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 164. Image file: Egensevej/Egensevej-2/cam1-04146.png
# Annotation #527: car
# Annotation #528: car
# Annotation #529: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 165. Image file: Egensevej/Egensevej-2/cam1-04154.png
# Annotation #530: car
# Annotation #531: car
# Annotation #532: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 166. Image file: Egensevej/Egensevej-2/cam1-04226.png
# Annotation #533: car
# Annotation #534: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 167. Image file: Egensevej/Egensevej-2/cam1-04349.png
# Annotation #535: car
# Annotation #536: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 168. Image file: Egensevej/Egensevej-2/cam1-04414.png
# Annotation #537: car
# Annotation #538: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 169. Image file: Egensevej/Egensevej-2/cam1-04442.png
# Annotation #539: car
# Annotation #540: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 170. Image file: Egensevej/Egensevej-2/cam1-04477.png
# Annotation #541: car
# Annotation #542: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 171. Image file: Egensevej/Egensevej-2/cam1-04493.png
# Annotation #543: car
# Annotation #544: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 172. Image file: Egensevej/Egensevej-2/cam1-04568.png
# Annotation #545: car
# Annotation #546: car
# Annotation #547: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 173. Image file: Egensevej/Egensevej-2/cam1-04592.png
# Annotation #548: car
# Annotation #549: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 174. Image file: Egensevej/Egensevej-2/cam1-04620.png
# Annotation #550: car
# Annotation #551: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 175. Image file: Egensevej/Egensevej-2/cam1-04649.png
# Annotation #552: car
# Annotation #553: car
# Annotation #554: car
# Annotation #555: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 176. Image file: Egensevej/Egensevej-2/cam1-04697.png
# Annotation #556: car
# Annotation #557: car
# Annotation #558: car
# Annotation #559: car
# Annotation #560: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 177. Image file: Egensevej/Egensevej-2/cam1-04805.png
# Annotation #561: car
# Annotation #562: car
# Annotation #563: car
# Annotation #564: car
# Annotation #565: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 178. Image file: Egensevej/Egensevej-2/cam1-04813.png
# Annotation #566: car
# Annotation #567: car
# Annotation #568: car
# Annotation #569: car
# Annotation #570: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 179. Image file: Egensevej/Egensevej-2/cam1-04868.png
# Annotation #571: car
# Annotation #572: car
# Annotation #573: car
# Annotation #574: car
# Annotation #575: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 180. Image file: Egensevej/Egensevej-2/cam1-04923.png
# Annotation #576: car
# Annotation #577: car
# Annotation #578: car
# Annotation #579: car
#
# RGB Image
# Thermal Image
# Found 3 annotations at image ID 181. Image file: Egensevej/Egensevej-2/cam1-04925.png
# Annotation #580: car
# Annotation #581: car
# Annotation #582: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 182. Image file: Egensevej/Egensevej-2/cam1-05063.png
# Annotation #583: car
# Annotation #584: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 183. Image file: Egensevej/Egensevej-2/cam1-05080.png
# Annotation #585: car
# Annotation #586: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 184. Image file: Egensevej/Egensevej-2/cam1-05220.png
# Annotation #587: car
# Annotation #588: car
# Annotation #589: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 185. Image file: Egensevej/Egensevej-2/cam1-05282.png
# Annotation #590: car
# Annotation #591: car
# Annotation #592: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 186. Image file: Egensevej/Egensevej-2/cam1-05293.png
# Annotation #593: car
# Annotation #594: car
# Annotation #595: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 187. Image file: Egensevej/Egensevej-2/cam1-05342.png
# Annotation #596: car
# Annotation #597: car
# Annotation #598: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 188. Image file: Egensevej/Egensevej-2/cam1-05371.png
# Annotation #599: car
# Annotation #600: car
# Annotation #601: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 189. Image file: Egensevej/Egensevej-2/cam1-05446.png
# Annotation #602: car
# Annotation #603: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 190. Image file: Egensevej/Egensevej-2/cam1-05474.png
# Annotation #604: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 191. Image file: Egensevej/Egensevej-2/cam1-05499.png
# Annotation #605: car
# Annotation #606: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 192. Image file: Egensevej/Egensevej-2/cam1-05529.png
# Annotation #607: car
# Annotation #608: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 193. Image file: Egensevej/Egensevej-2/cam1-05539.png
# Annotation #609: car
# Annotation #610: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 194. Image file: Egensevej/Egensevej-2/cam1-05683.png
# Annotation #611: car
# Annotation #612: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 195. Image file: Egensevej/Egensevej-2/cam1-05702.png
# Annotation #613: car
# Annotation #614: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 196. Image file: Egensevej/Egensevej-2/cam1-05714.png
# Annotation #615: car
# Annotation #616: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 197. Image file: Egensevej/Egensevej-2/cam1-05750.png
# Annotation #617: car
# Annotation #618: car
# Annotation #619: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 198. Image file: Egensevej/Egensevej-2/cam1-05831.png
# Annotation #620: car
# Annotation #621: car
# Annotation #622: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 199. Image file: Egensevej/Egensevej-2/cam1-05909.png
# Annotation #623: car
# Annotation #624: car
# Annotation #625: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 200. Image file: Egensevej/Egensevej-3/cam1-00002.png
# Annotation #653: car
# Annotation #654: car
# Annotation #655: car
# Annotation #656: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 201. Image file: Egensevej/Egensevej-3/cam1-00101.png
# Annotation #657: car
# Annotation #658: car
# Annotation #659: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 202. Image file: Egensevej/Egensevej-3/cam1-00161.png
# Annotation #660: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 203. Image file: Egensevej/Egensevej-3/cam1-00171.png
# Annotation #661: car
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 204. Image file: Egensevej/Egensevej-3/cam1-00549.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 205. Image file: Egensevej/Egensevej-3/cam1-00665.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 206. Image file: Egensevej/Egensevej-3/cam1-00792.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 207. Image file: Egensevej/Egensevej-3/cam1-00799.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 208. Image file: Egensevej/Egensevej-3/cam1-00822.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 209. Image file: Egensevej/Egensevej-3/cam1-00838.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 210. Image file: Egensevej/Egensevej-3/cam1-00862.png
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 211. Image file: Egensevej/Egensevej-3/cam1-01156.png
# Annotation #662: car
# Annotation #663: car
# Annotation #664: car
# Annotation #665: car
# Annotation #666: car
# Annotation #667: car
# Annotation #668: car
# Annotation #669: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 212. Image file: Egensevej/Egensevej-3/cam1-01239.png
# Annotation #670: car
# Annotation #671: car
# Annotation #672: car
# Annotation #673: car
# Annotation #674: car
# Annotation #675: car
# Annotation #676: car
# Annotation #677: car
# Annotation #678: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 213. Image file: Egensevej/Egensevej-3/cam1-01394.png
# Annotation #679: car
# Annotation #680: car
# Annotation #681: car
# Annotation #682: car
# Annotation #683: car
# Annotation #684: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 214. Image file: Egensevej/Egensevej-3/cam1-01413.png
# Annotation #685: car
# Annotation #686: car
# Annotation #687: car
# Annotation #688: car
# Annotation #689: car
# Annotation #690: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 215. Image file: Egensevej/Egensevej-3/cam1-01515.png
# Annotation #691: car
# Annotation #692: car
# Annotation #693: car
# Annotation #694: car
# Annotation #695: car
# Annotation #696: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 216. Image file: Egensevej/Egensevej-3/cam1-01647.png
# Annotation #697: car
# Annotation #698: car
# Annotation #699: car
# Annotation #700: car
# Annotation #701: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 217. Image file: Egensevej/Egensevej-3/cam1-01655.png
# Annotation #702: car
# Annotation #703: car
# Annotation #704: car
# Annotation #705: car
# Annotation #706: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 218. Image file: Egensevej/Egensevej-3/cam1-01742.png
# Annotation #707: car
# Annotation #708: car
# Annotation #709: car
# Annotation #710: car
# Annotation #711: car
# Annotation #712: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 219. Image file: Egensevej/Egensevej-3/cam1-01801.png
# Annotation #713: car
# Annotation #714: car
# Annotation #715: car
# Annotation #716: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 220. Image file: Egensevej/Egensevej-3/cam1-01802.png
# Annotation #717: car
# Annotation #718: car
# Annotation #719: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 221. Image file: Egensevej/Egensevej-3/cam1-01851.png
# Annotation #720: car
# Annotation #721: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 222. Image file: Egensevej/Egensevej-3/cam1-01857.png
# Annotation #722: car
# Annotation #723: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 223. Image file: Egensevej/Egensevej-3/cam1-01886.png
# Annotation #724: car
# Annotation #725: car
# Annotation #726: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 224. Image file: Egensevej/Egensevej-3/cam1-02042.png
# Annotation #727: car
# Annotation #728: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 225. Image file: Egensevej/Egensevej-3/cam1-02046.png
# Annotation #729: car
# Annotation #730: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 226. Image file: Egensevej/Egensevej-3/cam1-02069.png
# Annotation #731: car
# Annotation #732: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 227. Image file: Egensevej/Egensevej-3/cam1-02132.png
# Annotation #733: car
# Annotation #734: car
# Annotation #735: car
# Annotation #736: car
# Annotation #737: car
# Annotation #738: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 228. Image file: Egensevej/Egensevej-3/cam1-02143.png
# Annotation #739: car
# Annotation #740: car
# Annotation #741: car
# Annotation #742: car
# Annotation #743: car
# Annotation #744: car
#
# RGB Image
# Thermal Image
# Found 7 annotations at image ID 229. Image file: Egensevej/Egensevej-3/cam1-02351.png
# Annotation #745: car
# Annotation #746: car
# Annotation #747: car
# Annotation #748: car
# Annotation #749: car
# Annotation #750: car
# Annotation #751: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 230. Image file: Egensevej/Egensevej-3/cam1-02375.png
# Annotation #752: car
# Annotation #753: car
# Annotation #754: car
# Annotation #755: car
# Annotation #756: car
# Annotation #757: car
# Annotation #758: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 231. Image file: Egensevej/Egensevej-3/cam1-02415.png
# Annotation #759: car
# Annotation #760: car
# Annotation #761: car
# Annotation #762: car
# Annotation #763: car
# Annotation #764: car
# Annotation #765: car
# Annotation #766: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 232. Image file: Egensevej/Egensevej-3/cam1-02421.png
# Annotation #767: car
# Annotation #768: car
# Annotation #769: car
# Annotation #770: car
# Annotation #771: car
# Annotation #772: car
# Annotation #773: car
# Annotation #774: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 233. Image file: Egensevej/Egensevej-3/cam1-02446.png
# Annotation #775: car
# Annotation #776: car
# Annotation #777: car
# Annotation #778: car
# Annotation #779: car
# Annotation #780: car
# Annotation #781: car
# Annotation #782: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 234. Image file: Egensevej/Egensevej-3/cam1-02683.png
# Annotation #783: car
# Annotation #784: car
# Annotation #785: truck
# Annotation #786: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 235. Image file: Egensevej/Egensevej-3/cam1-02694.png
# Annotation #787: car
# Annotation #788: car
# Annotation #789: truck
# Annotation #790: car
# Annotation #791: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 236. Image file: Egensevej/Egensevej-3/cam1-02865.png
# Annotation #792: car
# Annotation #793: car
# Annotation #794: car
# Annotation #795: car
# Annotation #796: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 237. Image file: Egensevej/Egensevej-3/cam1-02963.png
# Annotation #797: car
# Annotation #798: car
# Annotation #799: car
# Annotation #800: car
# Annotation #801: car
# Annotation #802: car
# Annotation #803: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 238. Image file: Egensevej/Egensevej-3/cam1-03053.png
# Annotation #804: car
# Annotation #805: car
# Annotation #806: car
# Annotation #807: car
# Annotation #808: car
# Annotation #809: car
# Annotation #810: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 239. Image file: Egensevej/Egensevej-3/cam1-03060.png
# Annotation #811: car
# Annotation #812: car
# Annotation #813: car
# Annotation #814: car
# Annotation #815: car
# Annotation #816: car
# Annotation #817: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 240. Image file: Egensevej/Egensevej-3/cam1-03069.png
# Annotation #818: car
# Annotation #819: car
# Annotation #820: car
# Annotation #821: car
# Annotation #822: car
# Annotation #823: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 241. Image file: Egensevej/Egensevej-3/cam1-03097.png
# Annotation #824: car
# Annotation #825: car
# Annotation #826: car
# Annotation #827: car
# Annotation #828: car
# Annotation #829: car
# Annotation #830: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 242. Image file: Egensevej/Egensevej-3/cam1-03207.png
# Annotation #831: car
# Annotation #832: car
# Annotation #833: car
# Annotation #834: car
# Annotation #835: car
# Annotation #836: car
# Annotation #837: car
# Annotation #838: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 243. Image file: Egensevej/Egensevej-3/cam1-03285.png
# Annotation #839: car
# Annotation #840: car
# Annotation #841: car
# Annotation #842: car
# Annotation #843: car
# Annotation #844: car
# Annotation #845: car
# Annotation #846: car
# Annotation #847: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 244. Image file: Egensevej/Egensevej-3/cam1-03287.png
# Annotation #848: car
# Annotation #849: car
# Annotation #850: car
# Annotation #851: car
# Annotation #852: car
# Annotation #853: car
# Annotation #854: car
# Annotation #855: car
# Annotation #856: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 245. Image file: Egensevej/Egensevej-3/cam1-03317.png
# Annotation #857: car
# Annotation #858: car
# Annotation #859: car
# Annotation #860: car
# Annotation #861: car
# Annotation #862: car
# Annotation #863: car
# Annotation #864: car
# Annotation #865: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 246. Image file: Egensevej/Egensevej-3/cam1-03356.png
# Annotation #866: car
# Annotation #867: car
# Annotation #868: car
# Annotation #869: car
# Annotation #870: car
# Annotation #871: car
# Annotation #872: car
# Annotation #873: car
# Annotation #874: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 247. Image file: Egensevej/Egensevej-3/cam1-03361.png
# Annotation #875: car
# Annotation #876: car
# Annotation #877: car
# Annotation #878: car
# Annotation #879: car
# Annotation #880: car
# Annotation #881: car
# Annotation #882: car
# Annotation #883: car
#
# RGB Image
#
# Thermal Image
# Found 9 annotations at image ID 248. Image file: Egensevej/Egensevej-3/cam1-03411.png
# Annotation #884: car
# Annotation #885: car
# Annotation #886: car
# Annotation #887: car
# Annotation #888: car
# Annotation #889: car
# Annotation #890: car
# Annotation #891: car
# Annotation #892: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 249. Image file: Egensevej/Egensevej-3/cam1-03488.png
# Annotation #893: car
# Annotation #894: car
# Annotation #895: car
# Annotation #896: car
# Annotation #897: car
# Annotation #898: car
# Annotation #899: car
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 250. Image file: Egensevej/Egensevej-3/cam1-03502.png
# Annotation #900: car
# Annotation #901: car
# Annotation #902: car
# Annotation #903: car
# Annotation #904: car
# Annotation #905: car
# Annotation #906: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 251. Image file: Egensevej/Egensevej-3/cam1-03573.png
# Annotation #907: car
# Annotation #908: car
# Annotation #909: car
# Annotation #910: car
# Annotation #911: car
# Annotation #912: car
# Annotation #913: car
# Annotation #914: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 252. Image file: Egensevej/Egensevej-3/cam1-03619.png
# Annotation #915: car
# Annotation #916: car
# Annotation #917: car
# Annotation #918: car
# Annotation #919: car
# Annotation #920: car
# Annotation #921: car
# Annotation #922: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 253. Image file: Egensevej/Egensevej-3/cam1-03628.png
# Annotation #923: car
# Annotation #924: car
# Annotation #925: car
# Annotation #926: car
# Annotation #927: car
# Annotation #928: car
# Annotation #929: car
# Annotation #930: car
#
# RGB Image
#
# Thermal Image
# Found 8 annotations at image ID 254. Image file: Egensevej/Egensevej-3/cam1-03674.png
# Annotation #931: car
# Annotation #932: car
# Annotation #933: car
# ...
# Annotation #13012: bicycle
# Annotation #13013: car
# Annotation #13014: person
# Annotation #13015: car
# Annotation #13016: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2109. Image file: Ostre/Ostre-4/cam1-00705.png
# Annotation #13017: bicycle
# Annotation #13018: car
# Annotation #13019: person
# Annotation #13020: car
# Annotation #13021: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2110. Image file: Ostre/Ostre-4/cam1-00729.png
# Annotation #13022: bicycle
# Annotation #13023: car
# Annotation #13024: person
# Annotation #13025: car
# Annotation #13026: car
#
# RGB Image
# Thermal Image
# Found 6 annotations at image ID 2111. Image file: Ostre/Ostre-4/cam1-00811.png
# Annotation #13027: bicycle
# Annotation #13028: car
# Annotation #13029: person
# Annotation #13030: car
# Annotation #13031: car
# Annotation #13032: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2112. Image file: Ostre/Ostre-4/cam1-00841.png
# Annotation #13033: bicycle
# Annotation #13034: car
# Annotation #13035: person
# Annotation #13036: car
# Annotation #13037: car
# Annotation #13038: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2113. Image file: Ostre/Ostre-4/cam1-00925.png
# Annotation #13039: bicycle
# Annotation #13040: car
# Annotation #13041: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2114. Image file: Ostre/Ostre-4/cam1-00972.png
# Annotation #13042: bicycle
# Annotation #13043: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2115. Image file: Ostre/Ostre-4/cam1-01005.png
# Annotation #13044: bicycle
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2116. Image file: Ostre/Ostre-4/cam1-01025.png
# Annotation #13045: bicycle
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2117. Image file: Ostre/Ostre-4/cam1-01089.png
# Annotation #13046: bicycle
# Annotation #13047: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2118. Image file: Ostre/Ostre-4/cam1-01096.png
# Annotation #13048: bicycle
# Annotation #13049: car
# Annotation #13050: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2119. Image file: Ostre/Ostre-4/cam1-01115.png
# Annotation #13051: bicycle
# Annotation #13052: car
# Annotation #13053: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2120. Image file: Ostre/Ostre-4/cam1-01159.png
# Annotation #13054: bicycle
# Annotation #13055: car
# Annotation #13056: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2121. Image file: Ostre/Ostre-4/cam1-01164.png
# Annotation #13057: bicycle
# Annotation #13058: car
# Annotation #13059: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2122. Image file: Ostre/Ostre-4/cam1-01177.png
# Annotation #13060: bicycle
# Annotation #13061: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2123. Image file: Ostre/Ostre-4/cam1-01300.png
# Annotation #13062: bicycle
# Annotation #13063: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2124. Image file: Ostre/Ostre-4/cam1-01319.png
# Annotation #13064: bicycle
# Annotation #13065: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2125. Image file: Ostre/Ostre-4/cam1-01345.png
# Annotation #13066: bicycle
# Annotation #13067: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2126. Image file: Ostre/Ostre-4/cam1-01374.png
# Annotation #13068: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2127. Image file: Ostre/Ostre-4/cam1-01375.png
# Annotation #13069: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2128. Image file: Ostre/Ostre-4/cam1-01430.png
# Annotation #13070: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2129. Image file: Ostre/Ostre-4/cam1-01470.png
# Annotation #13071: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2130. Image file: Ostre/Ostre-4/cam1-01478.png
# Annotation #13072: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2131. Image file: Ostre/Ostre-4/cam1-01569.png
# Annotation #13073: car
# Annotation #13074: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2132. Image file: Ostre/Ostre-4/cam1-01580.png
# Annotation #13075: car
# Annotation #13076: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2133. Image file: Ostre/Ostre-4/cam1-01583.png
# Annotation #13077: car
# Annotation #13078: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2134. Image file: Ostre/Ostre-4/cam1-01654.png
# Annotation #13079: car
# Annotation #13080: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2135. Image file: Ostre/Ostre-4/cam1-01667.png
# Annotation #13081: car
# Annotation #13082: car
# Annotation #13083: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2136. Image file: Ostre/Ostre-4/cam1-01759.png
# Annotation #13084: car
# Annotation #13085: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2137. Image file: Ostre/Ostre-4/cam1-01785.png
# Annotation #13086: car
# Annotation #13276: bicycle
# Annotation #13284: bicycle
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2138. Image file: Ostre/Ostre-4/cam1-01875.png
# Annotation #13087: car
# Annotation #13275: car
# Annotation #13277: bicycle
# Annotation #13285: car
# Annotation #13286: bicycle
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2139. Image file: Ostre/Ostre-4/cam1-01964.png
# Annotation #13088: car
# Annotation #13089: car
# Annotation #13279: bicycle
# Annotation #13287: bicycle
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2140. Image file: Ostre/Ostre-4/cam1-01992.png
# Annotation #13090: car
# Annotation #13278: bicycle
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2141. Image file: Ostre/Ostre-4/cam1-02179.png
# Annotation #13091: car
# Annotation #13092: car
# Annotation #13093: car
# Annotation #13094: car
# Annotation #13095: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2142. Image file: Ostre/Ostre-4/cam1-02233.png
# Annotation #13096: car
# Annotation #13097: car
# Annotation #13098: car
# Annotation #13099: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2143. Image file: Ostre/Ostre-4/cam1-02321.png
# Annotation #13100: car
# Annotation #13101: car
# Annotation #13102: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2144. Image file: Ostre/Ostre-4/cam1-02387.png
# Annotation #13103: car
# Annotation #13104: car
# Annotation #13105: car
# Annotation #13106: car
# Annotation #13107: car
# Annotation #13108: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2145. Image file: Ostre/Ostre-4/cam1-02403.png
# Annotation #13109: car
# Annotation #13110: car
# Annotation #13111: car
# Annotation #13112: car
# Annotation #13113: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2146. Image file: Ostre/Ostre-4/cam1-02404.png
# Annotation #13114: car
# Annotation #13115: car
# Annotation #13116: car
# Annotation #13117: car
# Annotation #13118: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2147. Image file: Ostre/Ostre-4/cam1-02440.png
# Annotation #13119: car
# Annotation #13120: car
# Annotation #13121: car
# Annotation #13122: car
# Annotation #13123: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2148. Image file: Ostre/Ostre-4/cam1-02447.png
# Annotation #13124: car
# Annotation #13125: car
# Annotation #13126: car
# Annotation #13127: car
# Annotation #13128: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2149. Image file: Ostre/Ostre-4/cam1-02476.png
# Annotation #13129: car
# Annotation #13130: car
# Annotation #13131: car
# Annotation #13132: car
# Annotation #13133: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2150. Image file: Ostre/Ostre-4/cam1-02488.png
# Annotation #13134: car
# Annotation #13135: car
# Annotation #13136: car
# Annotation #13137: car
# Annotation #13138: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2151. Image file: Ostre/Ostre-4/cam1-02554.png
# Annotation #13139: car
# Annotation #13140: car
# Annotation #13141: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2152. Image file: Ostre/Ostre-4/cam1-02582.png
# Annotation #13142: car
# Annotation #13143: car
# Annotation #13144: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2153. Image file: Ostre/Ostre-4/cam1-02610.png
# Annotation #13145: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2154. Image file: Ostre/Ostre-4/cam1-02631.png
# Annotation #13146: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2155. Image file: Ostre/Ostre-4/cam1-02633.png
# Annotation #13147: car
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 2156. Image file: Ostre/Ostre-4/cam1-02835.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 2157. Image file: Ostre/Ostre-4/cam1-02865.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 2158. Image file: Ostre/Ostre-4/cam1-03046.png
#
# RGB Image
#
# Thermal Image
# Found 0 annotations at image ID 2159. Image file: Ostre/Ostre-4/cam1-03079.png
#
# RGB Image
# Thermal Image
# Found 2 annotations at image ID 2160. Image file: Ostre/Ostre-4/cam1-03129.png
# Annotation #13148: car
# Annotation #13149: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2161. Image file: Ostre/Ostre-4/cam1-03263.png
# Annotation #13150: car
# Annotation #13151: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2162. Image file: Ostre/Ostre-4/cam1-03382.png
# Annotation #13152: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2163. Image file: Ostre/Ostre-4/cam1-03454.png
# Annotation #13153: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2164. Image file: Ostre/Ostre-4/cam1-03455.png
# Annotation #13154: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2165. Image file: Ostre/Ostre-4/cam1-03602.png
# Annotation #13155: car
# Annotation #13156: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2166. Image file: Ostre/Ostre-4/cam1-03603.png
# Annotation #13157: car
# Annotation #13158: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2167. Image file: Ostre/Ostre-4/cam1-03726.png
# Annotation #13159: car
# Annotation #13160: car
# Annotation #13161: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2168. Image file: Ostre/Ostre-4/cam1-03825.png
# Annotation #13162: car
# Annotation #13163: car
# Annotation #13164: car
# Annotation #13165: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2169. Image file: Ostre/Ostre-4/cam1-03855.png
# Annotation #13166: car
# Annotation #13167: car
# Annotation #13168: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2170. Image file: Ostre/Ostre-4/cam1-04162.png
# Annotation #13169: car
# Annotation #13170: car
# Annotation #13171: car
# Annotation #13172: car
# Annotation #13173: car
# Annotation #13174: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2171. Image file: Ostre/Ostre-4/cam1-04168.png
# Annotation #13175: car
# Annotation #13176: car
# Annotation #13177: car
# Annotation #13178: car
# Annotation #13179: car
# Annotation #13180: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2172. Image file: Ostre/Ostre-4/cam1-04179.png
# Annotation #13181: car
# Annotation #13182: car
# Annotation #13183: car
# Annotation #13184: car
# Annotation #13185: car
# Annotation #13186: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2173. Image file: Ostre/Ostre-4/cam1-04195.png
# Annotation #13187: car
# Annotation #13188: car
# Annotation #13189: car
# Annotation #13190: car
# Annotation #13191: car
# Annotation #13192: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2174. Image file: Ostre/Ostre-4/cam1-04198.png
# Annotation #13193: car
# Annotation #13194: car
# Annotation #13195: car
# Annotation #13196: car
# Annotation #13197: car
# Annotation #13198: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2175. Image file: Ostre/Ostre-4/cam1-04234.png
# Annotation #13199: car
# Annotation #13200: car
# Annotation #13201: car
# Annotation #13202: car
# Annotation #13203: car
# Annotation #13204: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2176. Image file: Ostre/Ostre-4/cam1-04277.png
# Annotation #13205: car
# Annotation #13206: car
# Annotation #13207: car
# Annotation #13208: car
# Annotation #13209: car
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2177. Image file: Ostre/Ostre-4/cam1-04316.png
# Annotation #13210: car
# Annotation #13211: car
# Annotation #13212: car
# Annotation #13213: car
# Annotation #13214: car
# Annotation #13280: car
#
# RGB Image
#
# Thermal Image
# Found 5 annotations at image ID 2178. Image file: Ostre/Ostre-4/cam1-04333.png
# Annotation #13215: car
# Annotation #13216: car
# Annotation #13217: car
# Annotation #13218: car
# Annotation #13219: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2179. Image file: Ostre/Ostre-4/cam1-04419.png
# Annotation #13220: car
# Annotation #13221: car
# Annotation #13222: car
# Annotation #13223: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2180. Image file: Ostre/Ostre-4/cam1-04526.png
# Annotation #13224: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2181. Image file: Ostre/Ostre-4/cam1-04732.png
# Annotation #13225: car
# Annotation #13226: car
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2182. Image file: Ostre/Ostre-4/cam1-04842.png
# Annotation #13227: car
# Annotation #13228: car
# Annotation #13229: car
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2183. Image file: Ostre/Ostre-4/cam1-04899.png
# Annotation #13230: car
# Annotation #13231: car
# Annotation #13282: truck
# Annotation #13288: truck
#
# RGB Image
#
# Thermal Image
# Found 3 annotations at image ID 2184. Image file: Ostre/Ostre-4/cam1-04919.png
# Annotation #13232: car
# Annotation #13233: truck
# Annotation #13289: truck
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2185. Image file: Ostre/Ostre-4/cam1-04989.png
# Annotation #13234: truck
# Annotation #13290: truck
#
# RGB Image
#
# Thermal Image
# Found 6 annotations at image ID 2186. Image file: Ostre/Ostre-4/cam1-05111.png
# Annotation #13235: car
# Annotation #13236: car
# Annotation #13237: car
# Annotation #13238: car
# Annotation #13281: truck
# Annotation #13291: truck
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 2187. Image file: Ostre/Ostre-4/cam1-05197.png
# Annotation #13239: car
# Annotation #13240: car
# Annotation #13241: car
# Annotation #13242: car
# Annotation #13243: car
# Annotation #13283: truck
# Annotation #13292: truck
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 2188. Image file: Ostre/Ostre-4/cam1-05254.png
# Annotation #13244: car
# Annotation #13245: truck
# Annotation #13246: car
# Annotation #13247: car
# Annotation #13248: car
# Annotation #13249: car
# Annotation #13293: truck
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 2189. Image file: Ostre/Ostre-4/cam1-05437.png
# Annotation #13250: truck
# Annotation #13251: car
# Annotation #13252: car
# Annotation #13253: car
# Annotation #13254: car
# Annotation #13255: car
# Annotation #13294: truck
#
# RGB Image
#
# Thermal Image
# Found 7 annotations at image ID 2190. Image file: Ostre/Ostre-4/cam1-05476.png
# Annotation #13256: truck
# Annotation #13257: car
# Annotation #13258: car
# Annotation #13259: car
# Annotation #13260: car
# Annotation #13261: car
# Annotation #13295: truck
#
# RGB Image
#
# Thermal Image
# Found 4 annotations at image ID 2191. Image file: Ostre/Ostre-4/cam1-05547.png
# Annotation #13262: truck
# Annotation #13263: car
# Annotation #13264: car
# Annotation #13296: truck
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2192. Image file: Ostre/Ostre-4/cam1-05595.png
# Annotation #13265: car
#
# RGB Image
#
# Thermal Image
# Found 1 annotations at image ID 2193. Image file: Ostre/Ostre-4/cam1-05635.png
# Annotation #13266: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2194. Image file: Ostre/Ostre-4/cam1-05735.png
# Annotation #13267: car
# Annotation #13268: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2195. Image file: Ostre/Ostre-4/cam1-05931.png
# Annotation #13269: car
# Annotation #13270: car
#
# RGB Image
#
# Thermal Image
# Found 2 annotations at image ID 2196. Image file: Ostre/Ostre-4/cam1-05947.png
# Annotation #13271: car
# Annotation #13272: car
#
# RGB Image
#
# Thermal Image

# %% [markdown]
# ## Register an annotation in RGB to the thermal domain

# %%
import aauRainSnowUtility

chosenImgId = random.randint(0, 2197)
annIds = rainSnowRgbGt.getAnnIds(imgIds=[chosenImgId])
anns = rainSnowRgbGt.loadAnns(annIds)
rgbImg = rainSnowRgbGt.loadImgs([chosenImgId])[0]


if len(anns) > 0:
    chosenAnnId = random.randint(0, len(anns)-1)
    rgbAnn = anns[chosenAnnId]
    
    thermalSegmentation = []
    for segmentation in rgbAnn['segmentation']:
        thermalCoords = aauRainSnowUtility.registerRgbPointsToThermal(segmentation, rgbImg['file_name'])
        
        
        thermalSegmentation.append(thermalCoords)
        
        print('RGB coordinates for annotation ID ' + str(rgbAnn['id']) +':\n' + str(np.reshape(segmentation, (-1, 2))))
        print('Thermal coordinates:\n' + str(thermalCoords.reshape([-1, 2])))    
    
else:
    print("No annotations found for image ID " + str(chosenImgId) + ", try again")
# Out:
# Reading calibration file at: Ostre\Ostre-4-calib.yml
# RGB coordinates for annotation ID 13078:
# [[278 171]
#  [277 172]
#  [276 172]
#  [274 174]
#  [272 174]
#  [271 175]
#  [270 175]
#  [269 176]
#  [268 176]
#  [267 177]
#  [264 177]
#  [262 179]
#  [259 179]
#  [258 180]
#  [256 180]
#  [255 181]
#  [255 190]
#  [257 192]
#  [263 192]
#  [265 194]
#  [271 194]
#  [272 193]
#  [272 192]
#  [273 191]
#  [294 191]
#  [295 192]
#  [300 192]
#  [301 191]
#  [301 182]
#  [300 181]
#  [300 180]
#  [298 178]
#  [297 178]
#  [296 177]
#  [295 177]
#  [291 173]
#  [290 173]
#  [289 172]
#  [287 172]
#  [286 171]]
# Thermal coordinates:
# [[ 289.75698853   96.64176941]
#  [ 288.72457886   97.69309998]
#  [ 287.64135742   97.67044067]
#  [ 285.57553101   99.77651215]
#  [ 283.4083252    99.7338028 ]
#  [ 282.37481689  100.78890228]
#  [ 281.29101562  100.76847076]
#  [ 280.25720215  101.82481384]
#  [ 279.17321777  101.80510712]
#  [ 278.13909912  102.86266327]
#  [ 274.88674927  102.80677795]
#  [ 272.81747437  104.92660522]
#  [ 269.5645752   104.87606812]
#  [ 268.52954102  105.93827057]
#  [ 266.36090088  105.90704346]
#  [ 265.32568359  106.97075653]
#  [ 265.76925659  116.70098114]
#  [ 268.03872681  118.89910889]
#  [ 274.5501709   118.99971008]
#  [ 276.82122803  121.20513916]
#  [ 283.33273315  121.32193756]
#  [ 284.36709595  120.2578125 ]
#  [ 284.31643677  119.17347717]
#  [ 285.35064697  118.1105957 ]
#  [ 308.11026001  118.63024139]
#  [ 309.24435425  119.7419281 ]
#  [ 314.65301514  119.88899994]
#  [ 315.68200684  118.8365097 ]
#  [ 315.21185303  109.10999298]
#  [ 314.07891846  108.00052643]
#  [ 314.02658081  106.92247009]
#  [ 311.76049805  104.7065506 ]
#  [ 310.67953491  104.67646027]
#  [ 309.54626465  103.56993103]
#  [ 308.46499634  103.54051208]
#  [ 303.93109131   99.1233139 ]
#  [ 302.84933472   99.09555817]
#  [ 301.71575928   97.99356079]
#  [ 299.55169678   97.93981934]
#  [ 298.4180603    96.83930206]]

# %% [markdown]
# ## Register an annotation in thermal to the RGB domain

# %%
import aauRainSnowUtility

chosenImgId = random.randint(0, 2197)
annIds = rainSnowThermalGt.getAnnIds(imgIds=[chosenImgId])
anns = rainSnowThermalGt.loadAnns(annIds)
thermalImg = rainSnowThermalGt.loadImgs([chosenImgId])[0]


if len(anns) > 0:
    chosenAnnId = random.randint(0, len(anns)-1)
    thermalAnn = anns[chosenAnnId]
    
    rgbSegmentation = []
    for segmentation in thermalAnn['segmentation']:
        rgbCoords = aauRainSnowUtility.registerThermalPointsToRgb(segmentation, thermalImg['file_name'])
        
        
        rgbSegmentation.append(rgbCoords)
        
        print('Thermal coordinates for annotation ID ' + str(thermalAnn['id']) +':\n' + str(np.reshape(segmentation, (-1, 2))))
        print('RGB coordinates:\n' + str(rgbCoords.reshape([-1, 2])))    
    
else:
    print("No annotations found for image ID " + str(chosenImgId) + ", try again")
# Out:
# Reading calibration file at: Egensevej\Egensevej-2-calib.yml
# Thermal coordinates for annotation ID 635:
# [[ 402.4324646   148.91531372]
#  [ 399.33529663  152.08862305]
#  [ 399.57357788  163.01705933]
#  [ 400.65356445  164.14190674]
#  [ 411.19351196  164.46409607]
#  [ 412.22225952  163.40609741]
#  [ 413.27252197  163.43945312]
#  [ 414.30007935  162.38244629]
#  [ 414.09228516  152.5723114 ]
#  [ 413.0178833   151.44709778]
#  [ 412.99359131  150.35762024]
#  [ 411.9180603   149.23225403]]
# RGB coordinates:
# [[ 385.          175.        ]
#  [ 382.          178.        ]
#  [ 382.          188.        ]
#  [ 383.          189.        ]
#  [ 393.          189.        ]
#  [ 394.          188.        ]
#  [ 395.          188.        ]
#  [ 396.          187.        ]
#  [ 395.99996948  178.        ]
#  [ 395.          177.        ]
#  [ 395.          176.        ]
#  [ 394.          175.        ]]
